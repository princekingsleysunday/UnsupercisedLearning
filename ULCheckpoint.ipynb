# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
data = pd.read_csv('CC GENERAL.csv')

# %%
data
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
data.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
data.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
data.shape
# Out:
# (8950, 18)

# %%
# Listing numeric columns
v_n = list(data.select_dtypes(include=['float64', 'int64']).columns)

# %%
# Copy of DataFrame
data_norm = data.copy()

# %%
# Plot
plt.figure(figsize = (20,40))
x = 1
for column in v_n:
    plt.subplot(9, 3, x)
    sb.distplot(data_norm[column])
    plt.title('Distribution {}'.format(column), fontsize=10, color ='blue', fontweight = 'bold', y=0.90)
    x += 1

# %%
data
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
data.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %%
data['MINIMUM_PAYMENTS'].fillna(data['MINIMUM_PAYMENTS'].mean(), inplace = True)

data['CREDIT_LIMIT'].fillna(data['CREDIT_LIMIT'].mean(), inplace = True)

# %%
data.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
 new_data = data.drop(['CUST_ID'], axis = 1)

# %%
# check for outliers

# Outlier detection with Z-Score
from scipy import stats

z = np.abs(stats.zscore(data[['BALANCE','PURCHASES','ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS']]))
z
# Out:
#        BALANCE  PURCHASES  ONEOFF_PURCHASES_FREQUENCY  PURCHASES_TRX  \
# 0     0.731989   0.424900                    0.678661       0.511333
# 1     0.786961   0.469552                    0.678661       0.591796
# 2     0.447135   0.107668                    2.673451       0.109020
# 3     0.049099   0.232058                    0.399319       0.551565
# 4     0.358775   0.462063                    0.399319       0.551565
# ...        ...        ...                         ...            ...
# 8945  0.737950   0.333293                    0.678661       0.350408
# 8946  0.742423   0.329136                    0.678661       0.350408
# 8947  0.740398   0.401965                    0.678661       0.390639
# 8948  0.745174   0.469552                    0.678661       0.591796
# 8949  0.572575   0.042146                    1.556082       0.333524
#
#       CREDIT_LIMIT  PAYMENTS  MINIMUM_PAYMENTS
# 0         0.960433  0.528979      3.109675e-01
# ...

# %%
outliers = list(set(np.where(z > 3)[0]))
# new_df = data.drop(outliers,axis = 0).reset_index(drop = False)
# display(new_df)

len(outliers)
# Out:
# 641

# %%
new_data
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %% [markdown]
# # HIERARCHICAL

# %%
from sklearn.cluster import AgglomerativeClustering

model = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage ='complete')


model.fit(new_data)
# Out:
# AgglomerativeClustering(linkage='complete', n_clusters=5)

# %%
x = new_data[['BALANCE','BALANCE_FREQUENCY', 'CREDIT_LIMIT']]

model.fit(x)
# Out:
# AgglomerativeClustering(linkage='complete', n_clusters=5)

# %%
clust_label = model.fit_predict(x)

clust_df = pd.DataFrame(clust_label)

clust_df.value_counts()
# Out:
# 4    5836
# 3    2584
# 0     473
# 1      37
# 2      20
# dtype: int64

# %%
new_data
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
import matplotlib.pyplot as plt
fig =plt.figure()
ax = fig.add_subplot(111)
scatter = ax.scatter (data ["PURCHASES_TRX"] , data ["CREDIT_LIMIT"] , c= clust_df[0], s=50)

ax.set_title("Agglomerative Clustering")
ax.set_xlabel("PURCHASES_TRX")
ax.set_ylabel("CREDIT_LIMIT")
plt.colorbar(scatter)

# %%
new_data.shape
# Out:
# (8950, 17)

# %%
from sklearn.cluster import KMeans

model2 = KMeans(n_clusters=5, random_state=0) #cluster by choosing 5 as the number of clusters

x_train = x.loc[:7160]
x_test = x.loc[7160:]

model2.fit(x_train)
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
labels = pd.DataFrame(model2.labels_)

labels.head()
# Out:
#    0
# 0  1
# 1  3
# 2  2
# 3  2
# 4  1

# %%
new_data2 = pd.concat([data.loc[:7160],labels], axis=1)

new_data.iloc[5].rename({
    0: 'Cluster Labels'
})
# Out:
# BALANCE                             1809.828751
# BALANCE_FREQUENCY                      1.000000
# PURCHASES                           1333.280000
# ONEOFF_PURCHASES                       0.000000
# INSTALLMENTS_PURCHASES              1333.280000
# CASH_ADVANCE                           0.000000
# PURCHASES_FREQUENCY                    0.666667
# ONEOFF_PURCHASES_FREQUENCY             0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY       0.583333
# CASH_ADVANCE_FREQUENCY                 0.000000
# CASH_ADVANCE_TRX                       0.000000
# PURCHASES_TRX                          8.000000
# CREDIT_LIMIT                        1800.000000
# PAYMENTS                            1400.057770
# MINIMUM_PAYMENTS                    2407.246035
# PRC_FULL_PAYMENT                       0.000000
# TENURE                                12.000000
# Name: 5, dtype: float64

# %%
new_data2.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
# Prediction
y_pred = model2.predict(x_test)

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
model2.cluster_centers_
# Out:
# array([[ 4.76529768e+03,  9.23814228e-01,  1.36540365e+04,
#          9.71539424e+03,  3.93888141e+03,  3.68064874e+03,
#          8.34881402e-01,  6.84255609e-01,  6.77667989e-01,
#          1.50938707e-01,  7.15217391e+00,  1.00402174e+02,
#          1.32010870e+04,  1.92513615e+04,  2.64996567e+03,
#          3.88310478e-01,  1.19565217e+01],
#        [ 9.87752112e+02,  8.66412198e-01,  5.37518226e+02,
#          2.78310281e+02,  2.59531415e+02,  5.47547698e+02,
#          4.31933920e-01,  1.44632826e-01,  3.20308068e-01,
#          1.14603917e-01,  2.40825472e+00,  9.69740566e+00,
#          2.54397419e+03,  1.01167924e+03,  6.21307679e+02,
#          1.27358133e-01,  1.15424528e+01],
#        [ 1.63325933e+03,  9.07298393e-01,  1.67949428e+03,
#          1.07100532e+03,  6.08938623e+02,  6.37234464e+02,
#          6.19498648e-01,  3.70019407e-01,  4.29592070e-01,
#          9.62168445e-02,  2.09195956e+00,  2.33485797e+01,
# ...

# %%
from sklearn.metrics import silhouette_score
print(f'Silhouette Score(n=2):{silhouette_score(x_test, y_pred)}')
# Out:
# Silhouette Score(n=2):0.5529617825201857

# %%
print(f'Silhouette Score(n=2):{silhouette_score(x_train, model2.predict(x_train))}')
# Out:
# Silhouette Score(n=2):0.3660525651832093

# %%
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(10,7))
plt.title("Customer Dendrograms")
dend=shc.dendrogram(shc.linkage(new_data, method="complete"))
